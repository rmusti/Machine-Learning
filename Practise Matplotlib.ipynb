# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
plt.plot([1,2,3,4,5])

# %%
plt.plot([1,2,3,4,5] ,'rx')

# %%
plt.axis([0,5,0,10] )
plt.plot([1,2,3,4,5])
plt.title('My first Titkle')
plt.show()

# %%
plt.axis([0,5,0,10] )
plt.plot([1,2,3,4,5])
plt.title('My first Titkle')
plt.show()

# %%
t = np.arange(9)*0.2

y1 = np.sin(math.pi *t)
y2 = np.sin(math.pi *t*2)

plt.plot(t,y1,y2)

# %%
t = np.arange(9)*0.2

y1 = np.sin(math.pi *t)
y2 = np.sin(math.pi *t*2)

plt.plot(t,y1,t,y2,)

# %%
t = np.arange(0,9,.3)*0.2

y1 = np.sin(math.pi *t)
y2 = np.sin(math.pi *t*2)

plt.plot(t,y1,'b--',t,y2,'g--')

# %%
t = np.arange(0,9,.3)*0.2

y1 = np.sin(math.pi *t)
y2 = np.sin(math.pi *t*2)

plt.subplot(221)
plt.grid(True)
plt.plot(t,y1,'b--.')
plt.subplot(222)
plt.plot(t,y2,'r--.')
plt.subplot(223)
plt.plot(t,y1,'b--')
plt.subplot(224)
plt.plot(t,y2,'g--.')
